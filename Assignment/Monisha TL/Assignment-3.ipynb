# %% [markdown]
# ## import support libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the Dataset

# %%
df=pd.read_csv("C:\\Users\\monis\\Downloads\\abalone.csv")

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# ## Adding Age Column into Dataset

# %%
df=df.assign(Age=df.Rings+1.5)
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings   Age
# 0             0.1010        0.1500     15  16.5
# 1             0.0485        0.0700      7   8.5
# ...

# %% [markdown]
# ## Drop Rings column

# %%
df1=df.drop(columns=['Rings'],axis=1)

# %%
df1
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   Age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# ...

# %% [markdown]
# ## Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams

# %% [markdown]
# ## Univariate Analysis

# %%
sns.distplot(df1.Height)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.lineplot(df1.Age,df1.Diameter)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Diameter'>

# %% [markdown]
# ## Multivariate Analysis

# %%
sns.lineplot(df.Sex,df.Diameter,df.Age)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='Diameter'>

# %% [markdown]
# ## Descriptive Statistics

# %%
df1.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight          Age
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831    11.433684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     2.500000
# ...

# %% [markdown]
# ## Check for Missing Values

# %%
df1.isnull().any()
# Out:
# Sex               False
# Length            False
# Diameter          False
# Height            False
# Whole weight      False
# Shucked weight    False
# Viscera weight    False
# Shell weight      False
# Age               False
# dtype: bool

# %% [markdown]
# ## Check for Outliers

# %%
sns.boxplot(df1.Length)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Length'>

# %% [markdown]
# ## Replacing the outliers

# %%
df1.shape
# Out:
# (4177, 9)

# %%
q1=df1.Length.quantile(0.25)
q3=df1.Length.quantile(0.75)

# %%
IQR =q3-q1

# %%
upper_limit= q3 + 1.5*IQR
lower_limit= q1 - 1.5*IQR

# %%
df=df1[df1.Length>lower_limit]

# %%
sns.boxplot(df.Length)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Length'>

# %% [markdown]
# ## Check for Categorical Columns & Perform Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df.Sex=le.fit_transform(df.Sex)
df.head()
# Out:
# C:\Users\monis\AppData\Local\Temp\ipykernel_18168\1866830744.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Sex=le.fit_transform(df.Sex)
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight   Age
# 0          0.1010         0.150  16.5
# 1          0.0485         0.070   8.5
# 2          0.1415         0.210  10.5
# 3          0.1140         0.155  11.5
# ...

# %% [markdown]
# ## Split into Dependent & Independent Variables

# %%
y=df['Age']
y                              #dependent variable
# Out:
# 0       16.5
# 1        8.5
# 2       10.5
# 3       11.5
# 4        8.5
#         ...
# 4172    12.5
# 4173    11.5
# 4174    10.5
# 4175    11.5
# 4176    13.5
# Name: Age, Length: 4128, dtype: float64

# %%
X=df.drop(columns=['Age'],axis=1)
X.head()                            #independent variable
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight
# 0          0.1010         0.150
# 1          0.0485         0.070
# 2          0.1415         0.210
# 3          0.1140         0.155
# 4          0.0395         0.055

# %% [markdown]
# ## Split Train & Test

# %%
df.shape
# Out:
# (4128, 9)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (3302, 8)

# %%
x_test.shape
# Out:
# (826, 8)

# %% [markdown]
# ## Model Building

# %%
from sklearn.linear_model import LinearRegression

# %%
model= LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 9.38299513,  9.2677705 , 10.3268911 , 11.10258436, 11.20785166,
#        14.00047271, 10.5846742 , 15.8665931 ,  9.7482098 , 10.00633205,
#        10.06193542,  9.42426866, 12.01082503, 12.50119106, 12.14677352,
#        12.92006629, 12.6940112 , 14.17408644, 12.80535484,  8.86950333,
#        11.15983417,  8.58138481,  9.88358921, 10.84821136, 12.91066015,
#        13.69006878,  8.6315707 , 14.02029433, 10.52810191, 13.00546753,
#        14.85193445,  9.83180109,  9.62864671, 10.86670795,  7.26851155,
#         9.40399656,  9.48050481,  8.56715892, 12.31698066, 11.8034368 ,
#        12.82131536, 15.40929532, 10.65675857, 13.82945058, 11.18259052,
#        14.66185991, 12.7317864 ,  8.74523844, 10.59065039, 13.08693313,
#         9.81151779, 14.05545264, 11.44151136,  8.31023808, 12.39072408,
#         8.62645168, 13.7861168 , 11.30806428,  7.95938508, 11.90228858,
#         8.45173614, 12.77012843, 10.73643613, 10.85987223, 10.70566665,
# ...

# %%
y_test
# Out:
# 1088     7.5
# 45       8.5
# 1594     8.5
# 1304    10.5
# 3290    13.5
#         ...
# 179     12.5
# 50       9.5
# 64       9.5
# 1544     7.5
# 3474     7.5
# Name: Age, Length: 826, dtype: float64

# %%
pred_train=model.predict(x_train)
pred_train
# Out:
# array([14.8840636 ,  9.08923858, 11.74439024, ..., 12.91213758,
#         9.55035694, 10.3764185 ])

# %% [markdown]
# ## Evaluating the Model

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
## Confusion matrix
pd.crosstab(y_test,y_pred)       ## more or less correct prediction
# Out:
# col_0  4.342549   7.018036   7.082073   7.088490   7.119581   7.175478   \
# Age
# 4.5            0          0          0          1          0          0
# 5.5            0          1          1          0          0          0
# 6.5            0          0          0          0          1          1
# 7.5            0          0          0          0          0          0
# 8.5            1          0          0          0          0          0
# 9.5            0          0          0          0          0          0
# 10.5           0          0          0          0          0          0
# 11.5           0          0          0          0          0          0
# 12.5           0          0          0          0          0          0
# 13.5           0          0          0          0          0          0
# 14.5           0          0          0          0          0          0
# 15.5           0          0          0          0          0          0
# ...
